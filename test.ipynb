# %%
# Imports
import numpy as np
import pandas as pd
from sklearn import *
from sklearn import svm
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

# %%
# Data Processing
# params: String file
# return: DataFrame df
def import_data(file):
    df = pd.read_csv(file).drop_duplicates()
    # randomly sample 3000 hate speech
    hate = df.query('Class == "hate"').sample(n=3000).copy() 
    # randomly sample 3000 non-hate speech
    non_hate = df.query('Class == "none"').sample(n=3000).copy()
    # merge hate and non-hate
    df = pd.merge(hate, non_hate, how='outer').copy()

    return df

# Data Set Information Reporting
# params: DataFrame df
def data_stat(df):
    length = len(df)
    h_length = len(df.query('Class == "hate"'))
    n_length = len(df.query('Class == "none"'))
    print("\nNumber of samples:", length,"\nNumber of Hate Samples:", h_length, "\nNumber of non-Hate Samples:", n_length)

# Randomized Re-Annotation Sampling
# params: Dataframe df, float fn, float fp
# return: DataFrame rdf
def rand_annot_samp(df, fn, fp):

    rdf = df.copy()

    fn_tweets = df.query('Class == "hate"').sample(frac=fn).Tweets.tolist()
    fp_tweets = df.query('Class == "none"').sample(frac=fp).Tweets.tolist()

    for t in fn_tweets:
        rdf.loc[df["Tweets"] == t, "Class"] = "none"
    for t in fp_tweets:
        rdf.loc[df["Tweets"] == t, "Class"] = "hate"

    return rdf

''' TO-DO '''
# Intelligent Re-Annotation Sampling
# params: Dataframe df, float fn, float fp
# return: DataFrame idf
def inte_annot_samp(df, tweets):

    W_NORM = np.linalg.norm(clf.coef_)

    # iterate and calculate distance from tweet to model hyperplane
    # sort tweets by ascending order i.e. closest to hyperplane have higher priority
    # sample fp % of fp tweets and re-annotate
    # sample fn % of fn tweets and re-annotate
    # return updated df

    idf = df.copy()

    dist = []

    # generating distance list
    for tweet in tweets.iteritems():
        x = vectorizer.fit_transform([tweet[1]])
        x = x.toarray()

        zeros = [[0] for l in range(0,5000 - len(x[0]))]
        
        x = np.append(x,zeros)
        x = np.reshape(x,(1,-1))

        dist.append((clf.decision_function(x) / W_NORM)[0])

    # creating a new dict with tweets and their distance
    # fn_dict = {"Tweets" : fn_tweets.tolist(), "Distance" : fn_dist}
    # fp_dict = {"Tweets" : fp_tweets.tolist(), "Distance" : fp_dist}
    dict = {"Tweets" : tweets.tolist(), "Distance" : dist}

    # creating a new df with tweets and their distance
    # fn_df = pd.DataFrame.from_dict(fn_dict)
    # fp_df = pd.DataFrame.from_dict(fp_dict)
    new_df = pd.DataFrame.from_dict(dict)

    # sorting by distance in ascending order
    # fn_df.sort_values(by="Distance", inplace=True)
    # fp_df.sort_values(by="Distance", inplace=True)
    new_df.sort_values(by="Distance", inplace=True)
    new_df.head()
    # extracting sorted tweet order
    # fn_tweets = fn_df.Tweets.tolist()
    # fp_tweets = fp_df.Tweets.tolist()
    t = new_df.Tweets.tolist()

    # re-annotating
    # for i in range(0, FN_AMT):
    #     idf.loc[df["Tweets"] == fn_tweets[i], "Class"] = "none"
    # for i in range(0, FP_AMT):
    #     idf.loc[df["Tweets"] == fp_tweets[i], "Class"] = "hate"

    # while distance < 0
    # re-annotate tweets
    # print i as number of re-annotations

    final = pd.merge(idf, new_df, how="outer")
    final.sort_values(by="Distance", inplace=True)
    
    i = 0
    for index, row in final.iterrows():
        tweet = row["Tweets"]
        dist = row["Distance"]

        if (dist >= 0):
            break

        if (row["Class"] == "hate"):
            print(dist, row["Class"])
            idf.loc[idf["Tweets"] == tweet, "Class"] = "none"
        if (row["Class"] == "none"):
            print(dist, row["Class"])
            idf.loc[idf["Tweets"] == tweet, "Class"] = "hate"
        i += 1
        
    print("\nTotal Amount of Re-annotations:", i)
    return idf

# %%
# Data Processing
df = import_data("dataset.csv")

# Data Set Info
data_stat(df)

# Data Split
X_train, X_test, Y_train, Y_test = train_test_split(df.Tweets, df.Class, test_size=0.2)

vectorizer = CountVectorizer(analyzer = "word",tokenizer = None,preprocessor = None,stop_words = None,max_features = 5000)

train_data_features = vectorizer.fit_transform(X_train)
train_data_features = train_data_features.toarray()

test_data_features = vectorizer.transform(X_test)
test_data_features = test_data_features.toarray()

# Classifier
clf=svm.SVC(kernel='linear', C=1.0)

print ("\nTraining Baseline SVM")
clf.fit(train_data_features,Y_train)

print ("\nTesting Baseline SVM")
predicted=clf.predict(test_data_features)

accuracy=np.mean(predicted==Y_test)

# TO-DO: Format Accuracy Str
print ("\nBaseline Accuracy: ",accuracy) 

t_dict = {"Tweets" : X_test, "Actual" : Y_test, "Predicted" : predicted}
df2 = pd.DataFrame(t_dict).reset_index()

fn_tweets = df2.query('Actual == "hate" and Actual != Predicted').Tweets.copy()
fp_tweets = df2.query('Actual == "none" and Actual != Predicted').Tweets.copy()

fn = len(fn_tweets) / len(df2)
fp = len(fp_tweets) / len(df2)



tweets = fn_tweets.append(fp_tweets) 
tweets = tweets.tolist()
# Out:
# Number of samples: 6000
# Number of Hate Samples: 3000
# Number of non-Hate Samples: 3000
#
# Training Baseline SVM
#
# Testing Baseline SVM
#
# Baseline Accuracy:  0.8183333333333334
# /var/folders/z0/3g7yf8vn5v13k19lxjkfpgmr0000gn/T/ipykernel_24677/1682220954.py:41: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets = fn_tweets.append(fp_tweets)

# %%
print(int(fp * 3000) + )
# Out:
# 544

# %%
W_NORM = np.linalg.norm(clf.coef_)
dist = []
idf = df.copy()

for t in tweets:
    x = vectorizer.fit_transform([t])
    x = x.toarray()

    zeros = [[0] for l in range(0,5000 - len(x[0]))]
    
    x = np.append(x,zeros)
    x = np.reshape(x,(1,-1))

    dist.append((clf.decision_function(x) / W_NORM)[0])

dict = {"Tweets" : tweets, "Distance" : dist}

new_df = pd.DataFrame.from_dict(dict)

final = pd.merge(df, new_df)

final.sort_values(by="Distance", inplace=True)

p_to_n = 0
n_to_p = 0
for index, row in final.iterrows():
    tweet = row["Tweets"]
    dist = row["Distance"]

    if (row["Class"] == "hate" and p_to_n != int(fn * 3000)):
        print(tweet, dist, idf.loc[df["Tweets"] == tweet, "Class"])
        idf.loc[idf["Tweets"] == tweet, "Class"] = "none"
        print(tweet, dist, idf.loc[df["Tweets"] == tweet, "Class"])
        p_to_n += 1
    elif (row["Class"] == "none" and n_to_p != int(fp * 3000)):
        print(tweet, dist, idf.loc[df["Tweets"] == tweet, "Class"])
        idf.loc[idf["Tweets"] == tweet, "Class"] = "hate"
        print(tweet, dist, idf.loc[df["Tweets"] == tweet, "Class"])
        n_to_p += 1
   
    if n_to_p == int(fp * 3000) and p_to_n == int(fn * 3000):
       break
        
print("\nTotal Amount of Re-annotations:", int(fp * 3000) + int(fn * 3000))
# Out:
# No one even likes you Kat &amp; Andre. You won't last long...#mkr -0.01934744600296756 712    hate
# Name: Class, dtype: object
# No one even likes you Kat &amp; Andre. You won't last long...#mkr -0.01934744600296756 712    none
# Name: Class, dtype: object
# @UseUrTongue You need serious help, Gags.  I hope you find it. http://t.co/W1u9n2sjMh -0.01934744600296756 1027    hate
# Name: Class, dtype: object
# @UseUrTongue You need serious help, Gags.  I hope you find it. http://t.co/W1u9n2sjMh -0.01934744600296756 1027    none
# Name: Class, dtype: object
# #mkr No No No No No No -0.003256843470238287 4413    none
# Name: Class, dtype: object
# #mkr No No No No No No -0.003256843470238287 4413    hate
# Name: Class, dtype: object
# I'm slowly finding people that I trust, but it's all so hard because I care *so much*. 0.00111988960130944 5989    none
# Name: Class, dtype: object
# I'm slowly finding people that I trust, but it's all so hard because I care *so much*. 0.00111988960130944 5989    hate
# Name: Class, dtype: object
# Were butchers but can't tell red poultry is not cooked..  #salmonellaqueens #MKR 0.0045954804204228995 614     hate
# 1240    hate
# 5374    none
# Name: Class, dtype: object
# Were butchers but can't tell red poultry is not cooked..  #salmonellaqueens #MKR 0.0045954804204228995 614     none
# 1240    none
# 5374    none
# Name: Class, dtype: object
# Were butchers but can't tell red poultry is not cooked..  #salmonellaqueens #MKR 0.0045954804204228995 614     none
# 1240    none
# 5374    none
# Name: Class, dtype: object
# Were butchers but can't tell red poultry is not cooked..  #salmonellaqueens #MKR 0.0045954804204228995 614     none
# 1240    none
# 5374    none
# Name: Class, dtype: object
# Were butchers but can't tell red poultry is not cooked..  #salmonellaqueens #MKR 0.0045954804204228995 614     none
# 1240    none
# 5374    none
# Name: Class, dtype: object
# Were butchers but can't tell red poultry is not cooked..  #salmonellaqueens #MKR 0.0045954804204228995 614     none
# 1240    none
# 5374    none
# Name: Class, dtype: object
# Were butchers but can't tell red poultry is not cooked..  #salmonellaqueens #MKR 0.0045954804204228995 614     none
# 1240    none
# 5374    none
# Name: Class, dtype: object
# Were butchers but can't tell red poultry is not cooked..  #salmonellaqueens #MKR 0.0045954804204228995 614     hate
# 1240    hate
# 5374    hate
# Name: Class, dtype: object
# The truth behind another elimination round...to get rid of #cuntandandre #mkr 0.0045954804204228995 4784    none
# Name: Class, dtype: object
# The truth behind another elimination round...to get rid of #cuntandandre #mkr 0.0045954804204228995 4784    hate
# Name: Class, dtype: object
# RT @nathanrice: How to piss off an anti-vaxer. http://t.co/Nb2KU3KM1s 0.0045954804204228995 5150    none
# Name: Class, dtype: object
# RT @nathanrice: How to piss off an anti-vaxer. http://t.co/Nb2KU3KM1s 0.0045954804204228995 5150    hate
# Name: Class, dtype: object
# @DomesticPirate @Vosnic @uomo389 Not arguing against abortion but for his choice, too. 0.0045954804204228995 989    hate
# Name: Class, dtype: object
# @DomesticPirate @Vosnic @uomo389 Not arguing against abortion but for his choice, too. 0.0045954804204228995 989    none
# Name: Class, dtype: object
# I'm tipping the salmon will be overcooked because the BBQ is too hot #MKR 0.0045954804204228995 4379    none
# Name: Class, dtype: object
# I'm tipping the salmon will be overcooked because the BBQ is too hot #MKR 0.0045954804204228995 4379    hate
# Name: Class, dtype: object
# Kat and Andre better fuck off this show quickly. Awful people #mkr 0.0045954804204228995 1593    hate
# Name: Class, dtype: object
# Kat and Andre better fuck off this show quickly. Awful people #mkr 0.0045954804204228995 1593    none
# Name: Class, dtype: object
# Were butchers but can't tell red poultry is not cooked..  #salmonellaqueens #MKR 0.0045954804204228995 614     hate
# 1240    hate
# 5374    hate
# Name: Class, dtype: object
# Were butchers but can't tell red poultry is not cooked..  #salmonellaqueens #MKR 0.0045954804204228995 614     none
# 1240    none
# 5374    none
# Name: Class, dtype: object
# @LBigmann Never saw.  It's perfect.  But, Twitter is not the same w/o her. 0.0045954804204228995 195    hate
# Name: Class, dtype: object
# @LBigmann Never saw.  It's perfect.  But, Twitter is not the same w/o her. 0.0045954804204228995 195    none
# Name: Class, dtype: object
# Were butchers but can't tell red poultry is not cooked..  #salmonellaqueens #MKR 0.0045954804204228995 614     none
# 1240    none
# 5374    none
# Name: Class, dtype: object
# Were butchers but can't tell red poultry is not cooked..  #salmonellaqueens #MKR 0.0045954804204228995 614     hate
# 1240    hate
# 5374    hate
# Name: Class, dtype: object
# #MKR Annie's never cooked on a BBQ before. See...she is an alien. 0.0045954804204228995 2211    hate
# Name: Class, dtype: object
# #MKR Annie's never cooked on a BBQ before. See...she is an alien. 0.0045954804204228995 2211    none
# Name: Class, dtype: object
# #mkr pretty sure that's how all the chicks walk at Mt Druitt Westpoint 0.02130045193212523 1757    hate
# Name: Class, dtype: object
# #mkr pretty sure that's how all the chicks walk at Mt Druitt Westpoint 0.02130045193212523 1757    none
# Name: Class, dtype: object
# For a selection of perfection, #superiorfruit !! #graceville #brisbane #foodie #mkr #goodfoodie… https://t.co/lFUTzymhMH 0.02130045193212523 2815    hate
# Name: Class, dtype: object
# For a selection of perfection, #superiorfruit !! #graceville #brisbane #foodie #mkr #goodfoodie… https://t.co/lFUTzymhMH 0.02130045193212523 2815    none
# Name: Class, dtype: object
# OK - get this off my FB page asap!
#
# #paleo #mkr http://t.co/n3Y2cItgLV 0.02130045193212523 4474    none
# Name: Class, dtype: object
# OK - get this off my FB page asap!
#
# #paleo #mkr http://t.co/n3Y2cItgLV 0.02130045193212523 4474    hate
# Name: Class, dtype: object
# I just noticed that Bey is wearing a Wonder Woman tshirt in her video, Blow. 0.02130045193212523 3692    none
# Name: Class, dtype: object
# I just noticed that Bey is wearing a Wonder Woman tshirt in her video, Blow. 0.02130045193212523 3692    hate
# Name: Class, dtype: object
# if it's a Kat and Annie showdown, the 'sudden death' could be literal. #mkr 0.02130045193212523 3857    none
# Name: Class, dtype: object
# if it's a Kat and Annie showdown, the 'sudden death' could be literal. #mkr 0.02130045193212523 3857    hate
# Name: Class, dtype: object
# @dultery Oh my...that is the trolling equivalent of a WMD.  A Meme of Mass Destruction. 0.02130045193212523 1140    hate
# Name: Class, dtype: object
# @dultery Oh my...that is the trolling equivalent of a WMD.  A Meme of Mass Destruction. 0.02130045193212523 1140    none
# Name: Class, dtype: object
# but, there is still the dolly magazine model competition once a year girls. #mkr 0.02130045193212523 1594    hate
# Name: Class, dtype: object
# but, there is still the dolly magazine model competition once a year girls. #mkr 0.02130045193212523 1594    none
# Name: Class, dtype: object
# Had to put a blanket over his crate, but Nimoy slept through the night. :) 0.02130045193212523 3539    none
# Name: Class, dtype: object
# Had to put a blanket over his crate, but Nimoy slept through the night. :) 0.02130045193212523 3539    hate
# Name: Class, dtype: object
# Hashtag killerblondes is the dickiest hashtag in all  #MKR history... Seriously... Why not #butcherthemodels 0.026051920184979427 3034    none
# Name: Class, dtype: object
# Hashtag killerblondes is the dickiest hashtag in all  #MKR history... Seriously... Why not #butcherthemodels 0.026051920184979427 3034    hate
# Name: Class, dtype: object
# @motorcitybellex @SATANPLSS ...she was seriously, right? 0.026245386978104267 2551    hate
# Name: Class, dtype: object
# @motorcitybellex @SATANPLSS ...she was seriously, right? 0.026245386978104267 2551    none
# Name: Class, dtype: object
# @FeministFailure @MaravillaTom What is the event? 0.026245386978104267 2473    hate
# Name: Class, dtype: object
# @FeministFailure @MaravillaTom What is the event? 0.026245386978104267 2473    none
# Name: Class, dtype: object
# @LucasDavid__ ..says an unthinking pussy.  Yawn. 0.026245386978104267 1304    hate
# Name: Class, dtype: object
# @LucasDavid__ ..says an unthinking pussy.  Yawn. 0.026245386978104267 1304    none
# Name: Class, dtype: object
# FK YOU KAT AND ANDRE! #mkr 0.026245386978104267 1181    hate
# Name: Class, dtype: object
# FK YOU KAT AND ANDRE! #mkr 0.026245386978104267 1181    none
# Name: Class, dtype: object
# @MadamPlumpette I'm decent at editing, no worries ^.^ 0.026245386978104267 3912    none
# Name: Class, dtype: object
# @MadamPlumpette I'm decent at editing, no worries ^.^ 0.026245386978104267 3912    hate
# Name: Class, dtype: object
# What a riveting little lesson in walking the catwalk. Thanks ladies #MKR 0.028538406843813414 147     hate
# 1083    hate
# 5151    none
# Name: Class, dtype: object
# What a riveting little lesson in walking the catwalk. Thanks ladies #MKR 0.028538406843813414 147     none
# 1083    none
# 5151    none
# Name: Class, dtype: object
# What a riveting little lesson in walking the catwalk. Thanks ladies #MKR 0.028538406843813414 147     none
# 1083    none
# 5151    none
# Name: Class, dtype: object
# What a riveting little lesson in walking the catwalk. Thanks ladies #MKR 0.028538406843813414 147     hate
# 1083    hate
# 5151    hate
# Name: Class, dtype: object
# What a riveting little lesson in walking the catwalk. Thanks ladies #MKR 0.028538406843813414 147     hate
# 1083    hate
# 5151    hate
# Name: Class, dtype: object
# What a riveting little lesson in walking the catwalk. Thanks ladies #MKR 0.028538406843813414 147     none
# 1083    none
# 5151    none
# Name: Class, dtype: object
# So, that's a big double announcement for #mkr! What does everyone think? 0.028538406843813414 4916    none
# Name: Class, dtype: object
# So, that's a big double announcement for #mkr! What does everyone think? 0.028538406843813414 4916    hate
# Name: Class, dtype: object
# @EloisePeace haha and that is all they are good at #mkr 0.028538406843813414 2451    hate
# Name: Class, dtype: object
# @EloisePeace haha and that is all they are good at #mkr 0.028538406843813414 2451    none
# Name: Class, dtype: object
# What a riveting little lesson in walking the catwalk. Thanks ladies #MKR 0.028538406843813414 147     none
# 1083    none
# 5151    none
# Name: Class, dtype: object
# What a riveting little lesson in walking the catwalk. Thanks ladies #MKR 0.028538406843813414 147     hate
# 1083    hate
# 5151    hate
# Name: Class, dtype: object
# What a riveting little lesson in walking the catwalk. Thanks ladies #MKR 0.028538406843813414 147     hate
# 1083    hate
# 5151    hate
# Name: Class, dtype: object
# What a riveting little lesson in walking the catwalk. Thanks ladies #MKR 0.028538406843813414 147     none
# 1083    none
# 5151    none
# Name: Class, dtype: object
# @LOTRQuotes69 I'm sure your middle school teachers think you're just charming. 0.028538406843813414 5790    none
# Name: Class, dtype: object
# @LOTRQuotes69 I'm sure your middle school teachers think you're just charming. 0.028538406843813414 5790    hate
# Name: Class, dtype: object
# What a riveting little lesson in walking the catwalk. Thanks ladies #MKR 0.028538406843813414 147     none
# 1083    none
# 5151    none
# Name: Class, dtype: object
# What a riveting little lesson in walking the catwalk. Thanks ladies #MKR 0.028538406843813414 147     none
# 1083    none
# 5151    none
# Name: Class, dtype: object
# Absolutely #blondemoment #MKR 0.029719005920530856 197     hate
# 1369    hate
# 5667    none
# Name: Class, dtype: object
# Absolutely #blondemoment #MKR 0.029719005920530856 197     hate
# 1369    hate
# 5667    hate
# Name: Class, dtype: object
# Kats a RAT #mkr 0.029719005920530856 5578    none
# Name: Class, dtype: object
# Kats a RAT #mkr 0.029719005920530856 5578    hate
# Name: Class, dtype: object
# Absolutely #blondemoment #MKR 0.029719005920530856 197     hate
# 1369    hate
# 5667    hate
# Name: Class, dtype: object
# Absolutely #blondemoment #MKR 0.029719005920530856 197     none
# 1369    none
# 5667    none
# Name: Class, dtype: object
# Absolutely #blondemoment #MKR 0.029719005920530856 197     none
# 1369    none
# 5667    none
# Name: Class, dtype: object
# Absolutely #blondemoment #MKR 0.029719005920530856 197     none
# 1369    none
# 5667    none
# Name: Class, dtype: object
# #MKR Kat is better TV. She is a natural villian unlike Ash who is a fake one. 0.030803388437833586 4926    none
# Name: Class, dtype: object
# #MKR Kat is better TV. She is a natural villian unlike Ash who is a fake one. 0.030803388437833586 4926    hate
# Name: Class, dtype: object
# @EvanSutton96 More exclamation points = more truth, fact 0.030996855230958447 3815    none
# Name: Class, dtype: object
# @EvanSutton96 More exclamation points = more truth, fact 0.030996855230958447 3815    hate
# Name: Class, dtype: object
# "raped" is not a synonym for "touched" @magconboysthe He just got raped by that water https://t.co/sFPJE0dmqX 0.0324217503614616 2557    hate
# Name: Class, dtype: object
# "raped" is not a synonym for "touched" @magconboysthe He just got raped by that water https://t.co/sFPJE0dmqX 0.0324217503614616 2557    none
# Name: Class, dtype: object
# @amberhasalamb ...in what way? 0.034470474173385036 1526    hate
# Name: Class, dtype: object
# @amberhasalamb ...in what way? 0.034470474173385036 1526    none
# Name: Class, dtype: object
# @TheShujaatAli I like a multimedia approach. 0.034470474173385036 654    hate
# Name: Class, dtype: object
# @TheShujaatAli I like a multimedia approach. 0.034470474173385036 654    none
# Name: Class, dtype: object
# @depenthene That's their goal. 0.034470474173385036 1214    hate
# Name: Class, dtype: object
# @depenthene That's their goal. 0.034470474173385036 1214    none
# Name: Class, dtype: object
# @RealTrumpsFeels ...or the fugly. 0.034470474173385036 2989    hate
# Name: Class, dtype: object
# @RealTrumpsFeels ...or the fugly. 0.034470474173385036 2989    none
# Name: Class, dtype: object
# @g56yu What is that? 0.034470474173385036 2809    hate
# Name: Class, dtype: object
# @g56yu What is that? 0.034470474173385036 2809    none
# Name: Class, dtype: object
# @CassandraYoung Name that state. 0.034470474173385036 2964    hate
# Name: Class, dtype: object
# @CassandraYoung Name that state. 0.034470474173385036 2964    none
# Name: Class, dtype: object
# @beerandfeminism @Wyowanderer777 Which is? 0.034470474173385036 2924    hate
# Name: Class, dtype: object
# @beerandfeminism @Wyowanderer777 Which is? 0.034470474173385036 2924    none
# Name: Class, dtype: object
# @antifempsycho2 Not in the EU... 0.03800505041536928 2598    hate
# Name: Class, dtype: object
# @antifempsycho2 Not in the EU... 0.03800505041536928 2598    none
# Name: Class, dtype: object
# @mcall Repeating the lies, I see. 0.03800505041536928 1087    hate
# Name: Class, dtype: object
# @mcall Repeating the lies, I see. 0.03800505041536928 1087    none
# Name: Class, dtype: object
# @LostSailorNY @AJM9588 @CFLancop So true. 0.03800505041536928 4444    none
# Name: Class, dtype: object
# @LostSailorNY @AJM9588 @CFLancop So true. 0.03800505041536928 4444    hate
# Name: Class, dtype: object
# .@chouhos @unoriginal_babe The blank stare. 0.03800505041536928 90    hate
# Name: Class, dtype: object
# .@chouhos @unoriginal_babe The blank stare. 0.03800505041536928 90    none
# Name: Class, dtype: object
# I HATE KATE &amp; ANDREA #mkr 0.03800505041536928 2630    hate
# Name: Class, dtype: object
# I HATE KATE &amp; ANDREA #mkr 0.03800505041536928 2630    none
# Name: Class, dtype: object
# @howmariefeels I think he's trolling, actually... 0.03800505041536928 1555    hate
# Name: Class, dtype: object
# @howmariefeels I think he's trolling, actually... 0.03800505041536928 1555    none
# Name: Class, dtype: object
# A 3 . . . suck on that whores #MKR 0.03800505041536928 2649    hate
# Name: Class, dtype: object
# A 3 . . . suck on that whores #MKR 0.03800505041536928 2649    none
# Name: Class, dtype: object
# @avacadosoup ...unless you learn propaganda. 0.03800505041536928 2487    hate
# Name: Class, dtype: object
# @avacadosoup ...unless you learn propaganda. 0.03800505041536928 2487    none
# Name: Class, dtype: object
# @JanelleBrindle @lancewalton So is "twat". 0.03800505041536928 2593    hate
# Name: Class, dtype: object
# @JanelleBrindle @lancewalton So is "twat". 0.03800505041536928 2593    none
# Name: Class, dtype: object
# New dress!!! http://t.co/extjriLnty 0.03800505041536928 3929    none
# Name: Class, dtype: object
# New dress!!! http://t.co/extjriLnty 0.03800505041536928 3929    hate
# Name: Class, dtype: object
# CYA KATIE AND NIKKI #mkr 0.03800505041536928 3879    none
# Name: Class, dtype: object
# CYA KATIE AND NIKKI #mkr 0.03800505041536928 3879    hate
# Name: Class, dtype: object
# Eugh piss off kat #mkr 0.03800505041536928 4801    none
# Name: Class, dtype: object
# Eugh piss off kat #mkr 0.03800505041536928 4801    hate
# Name: Class, dtype: object
# Nikki...Kermit the frog called and he wants his voice back #MKR #MKR2015 #KillerBlondes @mykitchenrules 0.03895061804369582 66      hate
# 346     hate
# 5297    none
# Name: Class, dtype: object
# Nikki...Kermit the frog called and he wants his voice back #MKR #MKR2015 #KillerBlondes @mykitchenrules 0.03895061804369582 66      hate
# 346     hate
# 5297    hate
# Name: Class, dtype: object
# Nikki...Kermit the frog called and he wants his voice back #MKR #MKR2015 #KillerBlondes @mykitchenrules 0.03895061804369582 66      hate
# 346     hate
# 5297    hate
# Name: Class, dtype: object
# Nikki...Kermit the frog called and he wants his voice back #MKR #MKR2015 #KillerBlondes @mykitchenrules 0.03895061804369582 66      none
# 346     none
# 5297    none
# Name: Class, dtype: object
# @mykitchenrules if the vapid duo of conceit get through tonight I'm not watching again #suicideblondes #mkr 0.03895061804369582 1137    hate
# Name: Class, dtype: object
# @mykitchenrules if the vapid duo of conceit get through tonight I'm not watching again #suicideblondes #mkr 0.03895061804369582 1137    none
# Name: Class, dtype: object
# Drasko should have been married to bambi (Annie).
# I think they're a 'perfect' annoying couple.  #MKR 0.03895061804369582 732    hate
# Name: Class, dtype: object
# Drasko should have been married to bambi (Annie).
# I think they're a 'perfect' annoying couple.  #MKR 0.03895061804369582 732    none
# Name: Class, dtype: object
# Nikki...Kermit the frog called and he wants his voice back #MKR #MKR2015 #KillerBlondes @mykitchenrules 0.03895061804369582 66      none
# 346     none
# 5297    none
# Name: Class, dtype: object
# Nikki...Kermit the frog called and he wants his voice back #MKR #MKR2015 #KillerBlondes @mykitchenrules 0.03895061804369582 66      none
# 346     none
# 5297    none
# Name: Class, dtype: object
# @FraaankSalazar Just saw it a few days ago.  It's brilliant.  Need fifty more like it... 0.039571208894552824 2403    hate
# Name: Class, dtype: object
# @FraaankSalazar Just saw it a few days ago.  It's brilliant.  Need fifty more like it... 0.039571208894552824 2403    none
# Name: Class, dtype: object
# @thereginamom @JDefiant9 @jeffj666 If Paul Elam said the same about women...you'd be screeching about it. 0.041092346163707716 1223    hate
# Name: Class, dtype: object
# @thereginamom @JDefiant9 @jeffj666 If Paul Elam said the same about women...you'd be screeching about it. 0.041092346163707716 1223    none
# Name: Class, dtype: object
# No wonder they are fucked, they are relying on Annies charm #MKR 0.04273096985313087 1335    hate
# Name: Class, dtype: object
# No wonder they are fucked, they are relying on Annies charm #MKR 0.04273096985313087 1335    none
# Name: Class, dtype: object
# nothing worse than a raw cock....oh wait....#MKR 0.04373325121516923 1383    hate
# 2462    hate
# 4247    none
# Name: Class, dtype: object
# nothing worse than a raw cock....oh wait....#MKR 0.04373325121516923 1383    none
# 2462    none
# 4247    none
# Name: Class, dtype: object
# nothing worse than a raw cock....oh wait....#MKR 0.04373325121516923 1383    none
# 2462    none
# 4247    none
# Name: Class, dtype: object
# nothing worse than a raw cock....oh wait....#MKR 0.04373325121516923 1383    hate
# 2462    hate
# 4247    hate
# Name: Class, dtype: object
# nothing worse than a raw cock....oh wait....#MKR 0.04373325121516923 1383    hate
# 2462    hate
# 4247    hate
# Name: Class, dtype: object
# nothing worse than a raw cock....oh wait....#MKR 0.04373325121516923 1383    none
# 2462    none
# 4247    none
# Name: Class, dtype: object
# Oh fuck. Vicky and Celine are back 😒 #mkr 0.04373325121516923 318    hate
# Name: Class, dtype: object
# Oh fuck. Vicky and Celine are back 😒 #mkr 0.04373325121516923 318    none
# Name: Class, dtype: object
# RT @missgypsyck: Sassy.. More like trashy #MKR2015 #MKR 0.04373325121516923 1327    hate
# Name: Class, dtype: object
# RT @missgypsyck: Sassy.. More like trashy #MKR2015 #MKR 0.04373325121516923 1327    none
# Name: Class, dtype: object
# why is their whole menu dick related?!?!?! #MKR 0.04373325121516923 250     hate
# 1802    hate
# 4968    none
# 5080    none
# Name: Class, dtype: object
# why is their whole menu dick related?!?!?! #MKR 0.04373325121516923 250     hate
# 1802    hate
# 4968    hate
# 5080    hate
# Name: Class, dtype: object
# why is their whole menu dick related?!?!?! #MKR 0.04373325121516923 250     hate
# 1802    hate
# 4968    hate
# 5080    hate
# Name: Class, dtype: object
# why is their whole menu dick related?!?!?! #MKR 0.04373325121516923 250     hate
# 1802    hate
# 4968    hate
# 5080    hate
# Name: Class, dtype: object
# @MisfitInChains @oldgfatherclock @venereveritas13 SANTA JUST *IS* WHITE 0.04373325121516923 1323    hate
# Name: Class, dtype: object
# @MisfitInChains @oldgfatherclock @venereveritas13 SANTA JUST *IS* WHITE 0.04373325121516923 1323    none
# Name: Class, dtype: object
# why is their whole menu dick related?!?!?! #MKR 0.04373325121516923 250     hate
# 1802    hate
# 4968    hate
# 5080    hate
# Name: Class, dtype: object
# why is their whole menu dick related?!?!?! #MKR 0.04373325121516923 250     hate
# 1802    hate
# 4968    hate
# 5080    hate
# Name: Class, dtype: object
# @JakSoulbright @Stan_Philo  Sorry to hear that.  Get well, man. 0.04373325121516923 146    hate
# Name: Class, dtype: object
# @JakSoulbright @Stan_Philo  Sorry to hear that.  Get well, man. 0.04373325121516923 146    none
# Name: Class, dtype: object
# RT @JiggaThatNigga_: @YesYoureSexist you don't understand my intent 0.04373325121516923 1606    hate
# Name: Class, dtype: object
# RT @JiggaThatNigga_: @YesYoureSexist you don't understand my intent 0.04373325121516923 1606    none
# Name: Class, dtype: object
# @Palle_Hoffstein @ashleylynch @CranBoonitz glad that your job is safe. :) 0.04373325121516923 3636    none
# Name: Class, dtype: object
# @Palle_Hoffstein @ashleylynch @CranBoonitz glad that your job is safe. :) 0.04373325121516923 3636    hate
# Name: Class, dtype: object
# Oh my lord... #blondemomentforthe #KillerBlondes @mykitchenrules #MKR 0.04373325121516923 1698    hate
# Name: Class, dtype: object
# Oh my lord... #blondemomentforthe #KillerBlondes @mykitchenrules #MKR 0.04373325121516923 1698    none
# Name: Class, dtype: object
# why is their whole menu dick related?!?!?! #MKR 0.04373325121516923 250     hate
# 1802    hate
# 4968    hate
# 5080    hate
# Name: Class, dtype: object
# why is their whole menu dick related?!?!?! #MKR 0.04373325121516923 250     none
# 1802    none
# 4968    none
# 5080    none
# Name: Class, dtype: object
# @witch_sniffer @auntysoapbox ...invented "dogging" videos but can't have Page 3. 0.04373325121516923 1749    hate
# Name: Class, dtype: object
# @witch_sniffer @auntysoapbox ...invented "dogging" videos but can't have Page 3. 0.04373325121516923 1749    none
# Name: Class, dtype: object
# why is their whole menu dick related?!?!?! #MKR 0.04373325121516923 250     none
# 1802    none
# 4968    none
# 5080    none
# Name: Class, dtype: object
# why is their whole menu dick related?!?!?! #MKR 0.04373325121516923 250     hate
# 1802    hate
# 4968    hate
# 5080    hate
# Name: Class, dtype: object
# tad ironic that celine chose to reference elephants. #mkr 0.04373325121516923 4059    none
# Name: Class, dtype: object
# tad ironic that celine chose to reference elephants. #mkr 0.04373325121516923 4059    hate
# Name: Class, dtype: object
# why is their whole menu dick related?!?!?! #MKR 0.04373325121516923 250     hate
# 1802    hate
# 4968    hate
# 5080    hate
# Name: Class, dtype: object
# why is their whole menu dick related?!?!?! #MKR 0.04373325121516923 250     none
# 1802    none
# 4968    none
# 5080    none
# Name: Class, dtype: object
# why is their whole menu dick related?!?!?! #MKR 0.04373325121516923 250     none
# 1802    none
# 4968    none
# 5080    none
# Name: Class, dtype: object
# why is their whole menu dick related?!?!?! #MKR 0.04373325121516923 250     none
# 1802    none
# 4968    none
# 5080    none
# Name: Class, dtype: object
# @MeReachingout @GodfreyElfwick ...a pitch perfect parody.  My bad. 0.04373325121516923 1508    hate
# Name: Class, dtype: object
# @MeReachingout @GodfreyElfwick ...a pitch perfect parody.  My bad. 0.04373325121516923 1508    none
# Name: Class, dtype: object
# @holliebakerlutz Why was she fired, do you know? 0.04373325121516923 2227    hate
# Name: Class, dtype: object
# @holliebakerlutz Why was she fired, do you know? 0.04373325121516923 2227    none
# Name: Class, dtype: object
# I think they're deconstraucted Pro . . . mowhores #MKR 0.04373325121516923 2398    hate
# Name: Class, dtype: object
# I think they're deconstraucted Pro . . . mowhores #MKR 0.04373325121516923 2398    none
# Name: Class, dtype: object
# @GailSimone Because patriarchy? Is this a trick question? 0.04373325121516923 3039    none
# Name: Class, dtype: object
# @GailSimone Because patriarchy? Is this a trick question? 0.04373325121516923 3039    hate
# Name: Class, dtype: object
# @xdannock maybe someone will use Kat's weber #mkr 0.04373325121516923 4502    none
# Name: Class, dtype: object
# @xdannock maybe someone will use Kat's weber #mkr 0.04373325121516923 4502    hate
# Name: Class, dtype: object
# @scm ooo. that's old school. i didn't even think of that. 0.04373325121516923 5688    none
# Name: Class, dtype: object
# @scm ooo. that's old school. i didn't even think of that. 0.04373325121516923 5688    hate
# Name: Class, dtype: object
# Kat &amp; André your PATHETIC #nomoresoseforyou #fuckwits  #mkr 0.04373325121516923 5848    none
# Name: Class, dtype: object
# Kat &amp; André your PATHETIC #nomoresoseforyou #fuckwits  #mkr 0.04373325121516923 5848    hate
# Name: Class, dtype: object
# Wow
# What a low life cow Kat is  #MKR 0.04373325121516923 4744    none
# Name: Class, dtype: object
# Wow
# What a low life cow Kat is  #MKR 0.04373325121516923 4744    hate
# Name: Class, dtype: object
# Love a subtle menu. Sausage, spatchCOCK, tart. Perfect. #MKR #whereisyourdignity 0.04373325121516923 475    hate
# Name: Class, dtype: object
# Love a subtle menu. Sausage, spatchCOCK, tart. Perfect. #MKR #whereisyourdignity 0.04373325121516923 475    none
# Name: Class, dtype: object
# @RyanSorge19 Hey, I had him on 3 of my 4 fantasy teams... 0.04373325121516923 2667    hate
# Name: Class, dtype: object
# @RyanSorge19 Hey, I had him on 3 of my 4 fantasy teams... 0.04373325121516923 2667    none
# Name: Class, dtype: object
# @JacquesCuze @KimoiDoutei @aussielung Opt in solves these problems. 0.04373325121516923 2663    hate
# Name: Class, dtype: object
# @JacquesCuze @KimoiDoutei @aussielung Opt in solves these problems. 0.04373325121516923 2663    none
# Name: Class, dtype: object
# @JDefiant9 I am tennis neutral.  Just setting up the joke. 0.04373325121516923 2635    hate
# Name: Class, dtype: object
# @JDefiant9 I am tennis neutral.  Just setting up the joke. 0.04373325121516923 2635    none
# Name: Class, dtype: object
# the blonde-hate is rather unbecoming. #mkr 0.04373325121516923 3134    none
# Name: Class, dtype: object
# the blonde-hate is rather unbecoming. #mkr 0.04373325121516923 3134    hate
# Name: Class, dtype: object
# Rape is not a punch line. http://t.co/H6EojCYisr @yungturd 0.04373325121516923 4594    none
# Name: Class, dtype: object
# Rape is not a punch line. http://t.co/H6EojCYisr @yungturd 0.04373325121516923 4594    hate
# Name: Class, dtype: object
# Hope the blonde cows don't make it through! #MKR 0.04373325121516923 494    hate
# Name: Class, dtype: object
# Hope the blonde cows don't make it through! #MKR 0.04373325121516923 494    none
# Name: Class, dtype: object
# You'll be laughing last #skankKat #mkr 0.04373325121516923 2526    hate
# Name: Class, dtype: object
# You'll be laughing last #skankKat #mkr 0.04373325121516923 2526    none
# Name: Class, dtype: object
# R u fucking kidding - catwalk - all that's missing is a pole #mkr 0.04373325121516923 370    hate
# Name: Class, dtype: object
# R u fucking kidding - catwalk - all that's missing is a pole #mkr 0.04373325121516923 370    none
# Name: Class, dtype: object
# RT @uberfeminist: Emotional Terrorism https://t.co/OnrVC8tOXv #TwitterFeminism 0.04373325121516923 2465    hate
# Name: Class, dtype: object
# RT @uberfeminist: Emotional Terrorism https://t.co/OnrVC8tOXv #TwitterFeminism 0.04373325121516923 2465    none
# Name: Class, dtype: object
# why is their whole menu dick related?!?!?! #MKR 0.04373325121516923 250     none
# 1802    none
# 4968    none
# 5080    none
# Name: Class, dtype: object
# why is their whole menu dick related?!?!?! #MKR 0.04373325121516923 250     none
# 1802    none
# 4968    none
# 5080    none
# Name: Class, dtype: object
# @archibaldcrane @LostSailorNY What a fucked up insult to MLK...wow. 0.04373325121516923 1293    hate
# Name: Class, dtype: object
# @archibaldcrane @LostSailorNY What a fucked up insult to MLK...wow. 0.04373325121516923 1293    none
# Name: Class, dtype: object
# @DavidicLineage I present Exhibits V-Z that #FeminismIsAwful http://t.co/xDh0uVQEl5 0.04373325121516923 2987    hate
# Name: Class, dtype: object
# @DavidicLineage I present Exhibits V-Z that #FeminismIsAwful http://t.co/xDh0uVQEl5 0.04373325121516923 2987    none
# Name: Class, dtype: object
# @MechaSauce @shoe0nhead ...you have an armpit licking fetish? 0.04373325121516923 333    hate
# Name: Class, dtype: object
# @MechaSauce @shoe0nhead ...you have an armpit licking fetish? 0.04373325121516923 333    none
# Name: Class, dtype: object
# Yes, WE'RE ridiculous. Rofling irl holy shit @noshirtkurt_ Feminists are ridiculous. 0.04602627108087832 4063    none
# Name: Class, dtype: object
# Yes, WE'RE ridiculous. Rofling irl holy shit @noshirtkurt_ Feminists are ridiculous. 0.04602627108087832 4063    hate
# Name: Class, dtype: object
# @a_little_opus Treating women like trophies, the shinier the better! Totally not sexist. 0.04602627108087832 4113    none
# Name: Class, dtype: object
# @a_little_opus Treating women like trophies, the shinier the better! Totally not sexist. 0.04602627108087832 4113    hate
# Name: Class, dtype: object
# Katie and Nikki, nice from afar but far from nice #MKR 0.04726782745715342 1518    hate
# Name: Class, dtype: object
# Katie and Nikki, nice from afar but far from nice #MKR 0.04726782745715342 1518    none
# Name: Class, dtype: object
# @ChrisWarcraft @Pixelfish in WoD, you see manrik and his wife as children. COME BAAAAACK. 0.04831126539108673 3517    none
# Name: Class, dtype: object
# @ChrisWarcraft @Pixelfish in WoD, you see manrik and his wife as children. COME BAAAAACK. 0.04831126539108673 3517    hate
# Name: Class, dtype: object
# Rape is not a synonym for "depleted." @Aarcayne Just raped my bank account with tuition. 0.04831126539108673 2071    hate
# Name: Class, dtype: object
# Rape is not a synonym for "depleted." @Aarcayne Just raped my bank account with tuition. 0.04831126539108673 2071    none
# Name: Class, dtype: object
# Gay fiancé is not going to cope being away from the fresh meat #MKR 0.04831126539108673 61      hate
# 127     hate
# 4561    none
# 5171    none
# Name: Class, dtype: object
# Gay fiancé is not going to cope being away from the fresh meat #MKR 0.04831126539108673 61      none
# 127     none
# 4561    none
# 5171    none
# Name: Class, dtype: object
# Gay fiancé is not going to cope being away from the fresh meat #MKR 0.04831126539108673 61      none
# 127     none
# 4561    none
# 5171    none
# Name: Class, dtype: object
# Gay fiancé is not going to cope being away from the fresh meat #MKR 0.04831126539108673 61      hate
# 127     hate
# 4561    hate
# 5171    hate
# Name: Class, dtype: object
# @Allehegens Walker is clearly the one Dems fear.  I don't know much about him, either. 0.04831126539108673 2274    hate
# Name: Class, dtype: object
# @Allehegens Walker is clearly the one Dems fear.  I don't know much about him, either. 0.04831126539108673 2274    none
# Name: Class, dtype: object
# Gay fiancé is not going to cope being away from the fresh meat #MKR 0.04831126539108673 61      hate
# 127     hate
# 4561    hate
# 5171    hate
# Name: Class, dtype: object
# Gay fiancé is not going to cope being away from the fresh meat #MKR 0.04831126539108673 61      hate
# 127     hate
# 4561    hate
# 5171    hate
# Name: Class, dtype: object
# @dultery @Dex_is_Dope No joke.  A Swedish lawmaker proposed requiring men to sit when they pee... 0.04831126539108673 2346    hate
# Name: Class, dtype: object
# @dultery @Dex_is_Dope No joke.  A Swedish lawmaker proposed requiring men to sit when they pee... 0.04831126539108673 2346    none
# Name: Class, dtype: object
# Gay fiancé is not going to cope being away from the fresh meat #MKR 0.04831126539108673 61      hate
# 127     hate
# 4561    hate
# 5171    hate
# Name: Class, dtype: object
# Gay fiancé is not going to cope being away from the fresh meat #MKR 0.04831126539108673 61      none
# 127     none
# 4561    none
# 5171    none
# Name: Class, dtype: object
# According to Holly from Geordie Shore, "Sassy - halfway between slut and classy" #MKR #MKR2015 0.04831126539108673 2018    hate
# Name: Class, dtype: object
# According to Holly from Geordie Shore, "Sassy - halfway between slut and classy" #MKR #MKR2015 0.04831126539108673 2018    none
# Name: Class, dtype: object
# Eat your words Kat, don't choke on them niw !!! Hahaha gotta love Karma #mkr 0.04831126539108673 622    hate
# Name: Class, dtype: object
# Eat your words Kat, don't choke on them niw !!! Hahaha gotta love Karma #mkr 0.04831126539108673 622    none
# Name: Class, dtype: object
# The girls can cook for me anytime. Just not hot pot... or spatchcock. #MKR 0.04831126539108673 1537    hate
# Name: Class, dtype: object
# The girls can cook for me anytime. Just not hot pot... or spatchcock. #MKR 0.04831126539108673 1537    none
# Name: Class, dtype: object
# @NatalieTudor I never watch these things...do they ask men anything? 0.0487189691746292 1738    hate
# Name: Class, dtype: object
# @NatalieTudor I never watch these things...do they ask men anything? 0.0487189691746292 1738    none
# Name: Class, dtype: object
# Hopefully someone cooks Drasko in the next ep of #MKR 0.0487189691746292 1008    hate
# 2910    hate
# 3131    none
# 5219    none
# Name: Class, dtype: object
# Hopefully someone cooks Drasko in the next ep of #MKR 0.0487189691746292 1008    hate
# 2910    hate
# 3131    hate
# 5219    hate
# Name: Class, dtype: object
# Hopefully someone cooks Drasko in the next ep of #MKR 0.0487189691746292 1008    hate
# 2910    hate
# 3131    hate
# 5219    hate
# Name: Class, dtype: object
# Hopefully someone cooks Drasko in the next ep of #MKR 0.0487189691746292 1008    none
# 2910    none
# 3131    none
# 5219    none
# Name: Class, dtype: object
# Hopefully someone cooks Drasko in the next ep of #MKR 0.0487189691746292 1008    none
# 2910    none
# 3131    none
# 5219    none
# Name: Class, dtype: object
# Hopefully someone cooks Drasko in the next ep of #MKR 0.0487189691746292 1008    none
# 2910    none
# 3131    none
# 5219    none
# Name: Class, dtype: object
# RT @JustLaurenB: .@bowtie_guy14 @TheGags29 @aQmohra @MyLostGadget @MT8_9 http://t.co/tm3DJC61jw 0.0487189691746292 5750    none
# Name: Class, dtype: object
# RT @JustLaurenB: .@bowtie_guy14 @TheGags29 @aQmohra @MyLostGadget @MT8_9 http://t.co/tm3DJC61jw 0.0487189691746292 5750    hate
# Name: Class, dtype: object
# "Classy and elegant" is one way of putting it... #mkr 0.0487189691746292 965     hate
# 2648    hate
# 3677    none
# Name: Class, dtype: object
# "Classy and elegant" is one way of putting it... #mkr 0.0487189691746292 965     hate
# 2648    hate
# 3677    hate
# Name: Class, dtype: object
# @TrainInVainn @Druid2555 I determined you aren't worth such an effort.  Deal. 0.0487189691746292 2690    hate
# Name: Class, dtype: object
# @TrainInVainn @Druid2555 I determined you aren't worth such an effort.  Deal. 0.0487189691746292 2690    none
# Name: Class, dtype: object
# Haha Kate, wiped the smile off your face too #mkr 0.0487189691746292 3194    none
# Name: Class, dtype: object
# Haha Kate, wiped the smile off your face too #mkr 0.0487189691746292 3194    hate
# Name: Class, dtype: object
# "Classy and elegant" is one way of putting it... #mkr 0.0487189691746292 965     hate
# 2648    hate
# 3677    hate
# Name: Class, dtype: object
# "Classy and elegant" is one way of putting it... #mkr 0.0487189691746292 965     none
# 2648    none
# 3677    none
# Name: Class, dtype: object
# Colin looking very snazzy tonight, nice suit 👌✨#mkr @mykitchenrules @FourinHand 0.0487189691746292 5766    none
# Name: Class, dtype: object
# Colin looking very snazzy tonight, nice suit 👌✨#mkr @mykitchenrules @FourinHand 0.0487189691746292 5766    hate
# Name: Class, dtype: object
# Hopefully someone cooks Drasko in the next ep of #MKR 0.0487189691746292 1008    none
# 2910    none
# 3131    none
# 5219    none
# Name: Class, dtype: object
# Hopefully someone cooks Drasko in the next ep of #MKR 0.0487189691746292 1008    hate
# 2910    hate
# 3131    hate
# 5219    hate
# Name: Class, dtype: object
# When you encounter "patriarchy hurts men too!": http://t.co/n58sX7o2BY 0.0487189691746292 4398    none
# Name: Class, dtype: object
# When you encounter "patriarchy hurts men too!": http://t.co/n58sX7o2BY 0.0487189691746292 4398    hate
# Name: Class, dtype: object
# Not dumb blondes...mmm...perhaps just delusions of adequacy? #MKR 0.0487189691746292 1316    hate
# 2453    hate
# 5119    none
# Name: Class, dtype: object
# Not dumb blondes...mmm...perhaps just delusions of adequacy? #MKR 0.0487189691746292 1316    none
# 2453    none
# 5119    none
# Name: Class, dtype: object
# Not dumb blondes...mmm...perhaps just delusions of adequacy? #MKR 0.0487189691746292 1316    none
# 2453    none
# 5119    none
# Name: Class, dtype: object
# Not dumb blondes...mmm...perhaps just delusions of adequacy? #MKR 0.0487189691746292 1316    none
# 2453    none
# 5119    none
# Name: Class, dtype: object
# Not dumb blondes...mmm...perhaps just delusions of adequacy? #MKR 0.0487189691746292 1316    none
# 2453    none
# 5119    none
# Name: Class, dtype: object
# Not dumb blondes...mmm...perhaps just delusions of adequacy? #MKR 0.0487189691746292 1316    hate
# 2453    hate
# 5119    hate
# Name: Class, dtype: object
# @tpw_rules nothings broken. I was just driving througg a lot of water. 0.0487189691746292 3002    none
# Name: Class, dtype: object
# @tpw_rules nothings broken. I was just driving througg a lot of water. 0.0487189691746292 3002    hate
# Name: Class, dtype: object
# "Classy and elegant" is one way of putting it... #mkr 0.0487189691746292 965     none
# 2648    none
# 3677    none
# Name: Class, dtype: object
# "Classy and elegant" is one way of putting it... #mkr 0.0487189691746292 965     none
# 2648    none
# 3677    none
# Name: Class, dtype: object
# @OfficMattPenny @IrkMeIngram Ah, I see. Men "raise their voices." Women "scream." 0.0487189691746292 2841    hate
# Name: Class, dtype: object
# @OfficMattPenny @IrkMeIngram Ah, I see. Men "raise their voices." Women "scream." 0.0487189691746292 2841    none
# Name: Class, dtype: object
# @The_Loki_Jotunn @melisssugh Awesome.  Will go into my "daily use" folder. 0.0487189691746292 1669    hate
# Name: Class, dtype: object
# @The_Loki_Jotunn @melisssugh Awesome.  Will go into my "daily use" folder. 0.0487189691746292 1669    none
# Name: Class, dtype: object
# RT @immichaeldixon: Katie and Nikki, smug, vacuous, condescending, putrid, self congratulatory and bland. There. #MKR 0.050452993511098665 352     hate
# 893     hate
# 3664    none
# 5598    none
# Name: Class, dtype: object
# RT @immichaeldixon: Katie and Nikki, smug, vacuous, condescending, putrid, self congratulatory and bland. There. #MKR 0.050452993511098665 352     hate
# 893     hate
# 3664    hate
# 5598    hate
# Name: Class, dtype: object
# RT @immichaeldixon: Katie and Nikki, smug, vacuous, condescending, putrid, self congratulatory and bland. There. #MKR 0.050452993511098665 352     hate
# 893     hate
# 3664    hate
# 5598    hate
# Name: Class, dtype: object
# RT @immichaeldixon: Katie and Nikki, smug, vacuous, condescending, putrid, self congratulatory and bland. There. #MKR 0.050452993511098665 352     hate
# 893     hate
# 3664    hate
# 5598    hate
# Name: Class, dtype: object
# RT @immichaeldixon: Katie and Nikki, smug, vacuous, condescending, putrid, self congratulatory and bland. There. #MKR 0.050452993511098665 352     hate
# 893     hate
# 3664    hate
# 5598    hate
# Name: Class, dtype: object
# RT @immichaeldixon: Katie and Nikki, smug, vacuous, condescending, putrid, self congratulatory and bland. There. #MKR 0.050452993511098665 352     none
# 893     none
# 3664    none
# 5598    none
# Name: Class, dtype: object
# RT @immichaeldixon: Katie and Nikki, smug, vacuous, condescending, putrid, self congratulatory and bland. There. #MKR 0.050452993511098665 352     none
# 893     none
# 3664    none
# 5598    none
# Name: Class, dtype: object
# RT @immichaeldixon: Katie and Nikki, smug, vacuous, condescending, putrid, self congratulatory and bland. There. #MKR 0.050452993511098665 352     none
# 893     none
# 3664    none
# 5598    none
# Name: Class, dtype: object
# Sorry #killerblondes but you are a long LONG way from refined. #mkr 0.05225354541661341 1111    hate
# 2480    hate
# 3093    none
# Name: Class, dtype: object
# Sorry #killerblondes but you are a long LONG way from refined. #mkr 0.05225354541661341 1111    none
# 2480    none
# 3093    none
# Name: Class, dtype: object
# Sorry #killerblondes but you are a long LONG way from refined. #mkr 0.05225354541661341 1111    none
# 2480    none
# 3093    none
# Name: Class, dtype: object
# Sorry #killerblondes but you are a long LONG way from refined. #mkr 0.05225354541661341 1111    none
# 2480    none
# 3093    none
# Name: Class, dtype: object
# Sorry #killerblondes but you are a long LONG way from refined. #mkr 0.05225354541661341 1111    none
# 2480    none
# 3093    none
# Name: Class, dtype: object
# Sorry #killerblondes but you are a long LONG way from refined. #mkr 0.05225354541661341 1111    none
# 2480    none
# 3093    none
# Name: Class, dtype: object
# Sorry #killerblondes but you are a long LONG way from refined. #mkr 0.05225354541661341 1111    none
# 2480    none
# 3093    none
# Name: Class, dtype: object
# Sorry #killerblondes but you are a long LONG way from refined. #mkr 0.05225354541661341 1111    hate
# 2480    hate
# 3093    hate
# Name: Class, dtype: object
# Sorry #killerblondes but you are a long LONG way from refined. #mkr 0.05225354541661341 1111    hate
# 2480    hate
# 3093    hate
# Name: Class, dtype: object
# Sorry #killerblondes but you are a long LONG way from refined. #mkr 0.05225354541661341 1111    hate
# 2480    hate
# 3093    hate
# Name: Class, dtype: object
# Sorry #killerblondes but you are a long LONG way from refined. #mkr 0.05225354541661341 1111    hate
# 2480    hate
# 3093    hate
# Name: Class, dtype: object
# Sorry #killerblondes but you are a long LONG way from refined. #mkr 0.05225354541661341 1111    none
# 2480    none
# 3093    none
# Name: Class, dtype: object
# @beardyblue i'm drowning in email. we just started inputting them into a ticketing system to get through 'em. 0.0526023126922774 3801    none
# Name: Class, dtype: object
# @beardyblue i'm drowning in email. we just started inputting them into a ticketing system to get through 'em. 0.0526023126922774 3801    hate
# Name: Class, dtype: object
# I wonder who slept on this in tent?   Celine - I'm talking to you. #Burp  #mkr http://t.co/TZL1beY3sX 0.0526023126922774 2124    hate
# Name: Class, dtype: object
# I wonder who slept on this in tent?   Celine - I'm talking to you. #Burp  #mkr http://t.co/TZL1beY3sX 0.0526023126922774 2124    none
# Name: Class, dtype: object
# There goes your attempt at an "I'm such a deep dude" persona. @Thecolouredkid_ @YesYoureSexist suck my balls hoe 0.0526023126922774 782    hate
# Name: Class, dtype: object
# There goes your attempt at an "I'm such a deep dude" persona. @Thecolouredkid_ @YesYoureSexist suck my balls hoe 0.0526023126922774 782    none
# Name: Class, dtype: object
# "I believe in equality except when I'm drunk and mad at women." &lt;-- why I don't trust male feminists 0.0526023126922774 5501    none
# Name: Class, dtype: object
# "I believe in equality except when I'm drunk and mad at women." &lt;-- why I don't trust male feminists 0.0526023126922774 5501    hate
# Name: Class, dtype: object
# Deconstructed lemon tart, because we're too bloody lazy and incompetent to do it properly? #MKR 0.0526023126922774 4810    none
# Name: Class, dtype: object
# Deconstructed lemon tart, because we're too bloody lazy and incompetent to do it properly? #MKR 0.0526023126922774 4810    hate
# Name: Class, dtype: object
# The two accounts I reported (@fart2continue and @imh8bit) were both suspended, but this is not a good response. 0.0526023126922774 4440    none
# Name: Class, dtype: object
# The two accounts I reported (@fart2continue and @imh8bit) were both suspended, but this is not a good response. 0.0526023126922774 4440    hate
# Name: Class, dtype: object
# "It's Katie and Nikki to a T. In that it's trashy and cheap."
#
# #MKR 0.05561216554749533 613    hate
# Name: Class, dtype: object
# "It's Katie and Nikki to a T. In that it's trashy and cheap."
#
# #MKR 0.05561216554749533 613    none
# Name: Class, dtype: object
# @jkronenwetter18 So secure in his unshakeable faith in patriarchy that he banned me from retweeting his asinine reply 0.05833051349207737 4142    none
# Name: Class, dtype: object
# @jkronenwetter18 So secure in his unshakeable faith in patriarchy that he banned me from retweeting his asinine reply 0.05833051349207737 4142    hate
# Name: Class, dtype: object
# She can't hear you you little troll #mkr 0.06122111545223421 4425    none
# Name: Class, dtype: object
# She can't hear you you little troll #mkr 0.06122111545223421 4425    hate
# Name: Class, dtype: object
# Sassy? Gurls you ain't sassy. More like bitchy. #MKR 0.06122111545223421 33    hate
# Name: Class, dtype: object
# Sassy? Gurls you ain't sassy. More like bitchy. #MKR 0.06122111545223421 33    none
# Name: Class, dtype: object
# Kat is the biggest bitch I've ever had the displeasure of seeing in my life. #MKR 0.06596143150265729 4205    none
# Name: Class, dtype: object
# Kat is the biggest bitch I've ever had the displeasure of seeing in my life. #MKR 0.06596143150265729 4205    hate
# Name: Class, dtype: object
# @ChrisMMcDougall  He asked for it.  Did you?  Why not find an employer who will value you properly? 0.06625400734085896 105    hate
# Name: Class, dtype: object
# @ChrisMMcDougall  He asked for it.  Did you?  Why not find an employer who will value you properly? 0.06625400734085896 105    none
# Name: Class, dtype: object
# @girlziplocked whelp. I'm starting to get a pretty decent platform. I'm going to get his face out there, alright. &lt;3 0.07071289975551147 3144    none
# Name: Class, dtype: object
# @girlziplocked whelp. I'm starting to get a pretty decent platform. I'm going to get his face out there, alright. &lt;3 0.07071289975551147 3144    hate
# Name: Class, dtype: object
# @Wibbys Yeah men are known for being completely responsible drinkers who never puke. It's that Y chromosome, the "anti-puke" chromosome. 0.0734998238105168 5038    none
# Name: Class, dtype: object
# @Wibbys Yeah men are known for being completely responsible drinkers who never puke. It's that Y chromosome, the "anti-puke" chromosome. 0.0734998238105168 5038    hate
# Name: Class, dtype: object
# What's a decent RoR on 401(k)s? I've averaged 9.2% over the past few years. Not sure if that's decent or not. 0.073754035194323 3863    none
# Name: Class, dtype: object
# What's a decent RoR on 401(k)s? I've averaged 9.2% over the past few years. Not sure if that's decent or not. 0.073754035194323 3863    hate
# Name: Class, dtype: object
# Maybe your program forked until it could fork no longer, and you didn't have restrictions on. Maybe you sent an inappropriate amount of UDP. 0.07523629261362588 5220    none
# Name: Class, dtype: object
# ...
# Name: Class, dtype: object
# Good piece, but let's think of a new title. POC are still fighting for their civil rights, not time to yell "next." http://t.co/4irbAXiseL 0.10681368220652084 5010    hate
# Name: Class, dtype: object
# RT @schmeezi: @YesYoureSexist and what I tweet here is none of yours my employers or anyone's business. There's no way one can link it to m… 0.10681368220652084 4330    none
# Name: Class, dtype: object
# RT @schmeezi: @YesYoureSexist and what I tweet here is none of yours my employers or anyone's business. There's no way one can link it to m… 0.10681368220652084 4330    hate
# Name: Class, dtype: object
# Seems Eva &amp; Debra think they are michelin star chefs after their instant restaurant result. Don't quit your day jobs just yet #mkr 0.10681368220652084 4240    none
# Name: Class, dtype: object
# Seems Eva &amp; Debra think they are michelin star chefs after their instant restaurant result. Don't quit your day jobs just yet #mkr 0.10681368220652084 4240    hate
# Name: Class, dtype: object
# RT @Jrod__RigueZ I hate when women talk football but don't know what they're talking about It's only cute when you know your shit! #NoSexist 0.10800619228200041 1230    hate
# Name: Class, dtype: object
# RT @Jrod__RigueZ I hate when women talk football but don't know what they're talking about It's only cute when you know your shit! #NoSexist 0.10800619228200041 1230    none
# Name: Class, dtype: object
# Omg Kat and Andre are cooking at Mandurah crab fest this Saturday. I want to go just so I can flip her the bird!!! Skanky mole #mkr 0.10895821819902457 1029    hate
# Name: Class, dtype: object
# Omg Kat and Andre are cooking at Mandurah crab fest this Saturday. I want to go just so I can flip her the bird!!! Skanky mole #mkr 0.10895821819902457 1029    none
# Name: Class, dtype: object
# Today one of my students spoke loudly and openly about how it's unfair that women get shit for doing No Shave November. There is hope. 0.10895821819902457 1300    hate
# Name: Class, dtype: object
# Today one of my students spoke loudly and openly about how it's unfair that women get shit for doing No Shave November. There is hope. 0.10895821819902457 1300    none
# Name: Class, dtype: object
# RT @sir_lummox: @RichardMeal "Well son, you've scored a shitload of goals for the youth team, but we can't make you professional, because y… 0.10917505231107823 661    hate
# Name: Class, dtype: object
# RT @sir_lummox: @RichardMeal "Well son, you've scored a shitload of goals for the youth team, but we can't make you professional, because y… 0.10917505231107823 661    none
# Name: Class, dtype: object
# @Dreysander1 Hard to say.  I naively had my fun, not realizing the anvil above me.  I believe having that "fun" is key to later monogamy. 0.11102908468334939 1919    hate
# Name: Class, dtype: object
# @Dreysander1 Hard to say.  I naively had my fun, not realizing the anvil above me.  I believe having that "fun" is key to later monogamy. 0.11102908468334939 1919    none
# Name: Class, dtype: object
# CHORTLE @FollowFlow That blind date last night is why I don't do blind dates. All she did was call me sexist because I like being chivalrous 0.11156515045937503 5303    none
# Name: Class, dtype: object
# CHORTLE @FollowFlow That blind date last night is why I don't do blind dates. All she did was call me sexist because I like being chivalrous 0.11156515045937503 5303    hate
# Name: Class, dtype: object
# I think the real question is: why do you sign your tweets with KT? You realize that your name is right there, yeah? @kelseytheodore2 0.112014026234564 3590    none
# Name: Class, dtype: object
# I think the real question is: why do you sign your tweets with KT? You realize that your name is right there, yeah? @kelseytheodore2 0.112014026234564 3590    hate
# Name: Class, dtype: object
# This isn't even about the best cooking right now. Ugh.  I can't wait for things to get tougher so we can see Kat and Andre sweat. #mkr 0.11249279444100888 381    hate
# Name: Class, dtype: object
# This isn't even about the best cooking right now. Ugh.  I can't wait for things to get tougher so we can see Kat and Andre sweat. #mkr 0.11249279444100888 381    none
# Name: Class, dtype: object
# Sucked in Kat and Andre you should be embarrassed not just with your food but your behavior #karmaisabitch @mykitchenrules #mkr 0.11249308314382873 2718    hate
# Name: Class, dtype: object
# Sucked in Kat and Andre you should be embarrassed not just with your food but your behavior #karmaisabitch @mykitchenrules #mkr 0.11249308314382873 2718    none
# Name: Class, dtype: object
# “@LIncsgq: The girls could get a job at Hienz making baby food #MKR2015 #MKR” No! Think of the children! The children! 0.11281708792875117 5884    none
# Name: Class, dtype: object
# “@LIncsgq: The girls could get a job at Hienz making baby food #MKR2015 #MKR” No! Think of the children! The children! 0.11281708792875117 5884    hate
# Name: Class, dtype: object
# Notice how no one ever gives male gymnasts shit for being less flexible than female gymnasts, or says men can't play piccolo or some shit 0.11451145755531102 3433    none
# Name: Class, dtype: object
# Notice how no one ever gives male gymnasts shit for being less flexible than female gymnasts, or says men can't play piccolo or some shit 0.11451145755531102 3433    hate
# Name: Class, dtype: object
# Can we stop deconstructing desserts please? Let's start a campaign, let's get some names on a clipboard, let's start a march #mkr 0.11458885462536877 4193    none
# Name: Class, dtype: object
# Can we stop deconstructing desserts please? Let's start a campaign, let's get some names on a clipboard, let's start a march #mkr 0.11458885462536877 4193    hate
# Name: Class, dtype: object
# Out of Pravana blue. Guess I'm stuck with mixing some clear with Special FX Turquoise to layer over existing hair. hmm. This might be good. 0.11552207271242904 5639    none
# Name: Class, dtype: object
# Out of Pravana blue. Guess I'm stuck with mixing some clear with Special FX Turquoise to layer over existing hair. hmm. This might be good. 0.11552207271242904 5639    hate
# Name: Class, dtype: object
# @mykitchenrules If Katie and Nikki scored a point for every time they called them selves  pretty  they would score around 273,345 #mkr 0.11632148168634929 5089    none
# Name: Class, dtype: object
# @mykitchenrules If Katie and Nikki scored a point for every time they called them selves  pretty  they would score around 273,345 #mkr 0.11632148168634929 5089    hate
# Name: Class, dtype: object
# @newscomauHQ #mkr Kat=stupidity+bully. What goes around comes around.She will get what she deserves very soon.Go Rose &amp; Josh,Rob &amp; Lynzey! 0.11898047575817339 2039    hate
# Name: Class, dtype: object
# @newscomauHQ #mkr Kat=stupidity+bully. What goes around comes around.She will get what she deserves very soon.Go Rose &amp; Josh,Rob &amp; Lynzey! 0.11898047575817339 2039    none
# Name: Class, dtype: object
# No, I'm not telling anyone what their score is. Then it'll just turn into a contest for GamerGate to try to 'win'. 0.11899834841713927 4483    none
# Name: Class, dtype: object
# No, I'm not telling anyone what their score is. Then it'll just turn into a contest for GamerGate to try to 'win'. 0.11899834841713927 4483    hate
# Name: Class, dtype: object
# RT @CraigSJ: Live footage of Patricia Arquette asking gays &amp; people of color to help her get better pay. http://t.co/oDcIyqbknM 0.12007227575354304 1877    hate
# Name: Class, dtype: object
# RT @CraigSJ: Live footage of Patricia Arquette asking gays &amp; people of color to help her get better pay. http://t.co/oDcIyqbknM 0.12007227575354304 1877    none
# Name: Class, dtype: object
# Spreading rumors started by GNAA as fact when you call yourself a journalist is why I can't take you seriously. @georgieonthego 0.12256681513708619 5892    none
# Name: Class, dtype: object
# Spreading rumors started by GNAA as fact when you call yourself a journalist is why I can't take you seriously. @georgieonthego 0.12256681513708619 5892    hate
# Name: Class, dtype: object
# RT @colonelkickhead: Apparently walking a catwalk involves putting one foot in front of the other...you know, like walking #MKR 0.12256681513708619 4722    none
# Name: Class, dtype: object
# RT @colonelkickhead: Apparently walking a catwalk involves putting one foot in front of the other...you know, like walking #MKR 0.12256681513708619 4722    hate
# Name: Class, dtype: object
# Is #mkr sexist then? Four of the six teams in the fourth instant restaurants are an all-female team. 0.12256681513708619 416     hate
# 2248    hate
# 3345    none
# 4360    none
# Name: Class, dtype: object
# Is #mkr sexist then? Four of the six teams in the fourth instant restaurants are an all-female team. 0.12256681513708619 416     hate
# 2248    hate
# 3345    hate
# 4360    hate
# Name: Class, dtype: object
# Is #mkr sexist then? Four of the six teams in the fourth instant restaurants are an all-female team. 0.12256681513708619 416     hate
# 2248    hate
# 3345    hate
# 4360    hate
# Name: Class, dtype: object
# Is #mkr sexist then? Four of the six teams in the fourth instant restaurants are an all-female team. 0.12256681513708619 416     hate
# 2248    hate
# 3345    hate
# 4360    hate
# Name: Class, dtype: object
# Is #mkr sexist then? Four of the six teams in the fourth instant restaurants are an all-female team. 0.12256681513708619 416     hate
# 2248    hate
# 3345    hate
# 4360    hate
# Name: Class, dtype: object
# Is #mkr sexist then? Four of the six teams in the fourth instant restaurants are an all-female team. 0.12256681513708619 416     none
# 2248    none
# 3345    none
# 4360    none
# Name: Class, dtype: object
# Is #mkr sexist then? Four of the six teams in the fourth instant restaurants are an all-female team. 0.12256681513708619 416     none
# 2248    none
# 3345    none
# 4360    none
# Name: Class, dtype: object
# Is #mkr sexist then? Four of the six teams in the fourth instant restaurants are an all-female team. 0.12256681513708619 416     none
# 2248    none
# 3345    none
# 4360    none
# Name: Class, dtype: object
# #mkr #qldbesties Sheri I give you a 10 as eating otgans doesnt scare you.I like you to try new things and I  take you to your happy place 0.12489743085605434 4161    none
# Name: Class, dtype: object
# #mkr #qldbesties Sheri I give you a 10 as eating otgans doesnt scare you.I like you to try new things and I  take you to your happy place 0.12489743085605434 4161    hate
# Name: Class, dtype: object
# Why does @Twitter refresh TL to the top every 7th to 9th time I return from notifications...very annoying...lose many tweets I want to read. 0.12540868099777572 581    hate
# Name: Class, dtype: object
# Why does @Twitter refresh TL to the top every 7th to 9th time I return from notifications...very annoying...lose many tweets I want to read. 0.12540868099777572 581    none
# Name: Class, dtype: object
# .@Femitheist @ktonieskacze Hard to say w/o knowing if avg. welfare w/o a dad is &gt; or &lt; avg. CS payment.  If less, it would REDUCE incentive. 0.12605017346203837 2850    hate
# Name: Class, dtype: object
# .@Femitheist @ktonieskacze Hard to say w/o knowing if avg. welfare w/o a dad is &gt; or &lt; avg. CS payment.  If less, it would REDUCE incentive. 0.12605017346203837 2850    none
# Name: Class, dtype: object
# I'm pondering getting Leo a friend. Looking at shelter pics of the most adorable corgi/chihuahua mix right now. omg. omg omg. 0.12610122500445772 3004    none
# Name: Class, dtype: object
# I'm pondering getting Leo a friend. Looking at shelter pics of the most adorable corgi/chihuahua mix right now. omg. omg omg. 0.12610122500445772 3004    hate
# Name: Class, dtype: object
# Colin says the meat in the thigh was moist &amp; tender ??? Are you talking about the main dish or Nicki's thighs ? #MKR 0.1326500430657208 2731    hate
# Name: Class, dtype: object
# Colin says the meat in the thigh was moist &amp; tender ??? Are you talking about the main dish or Nicki's thighs ? #MKR 0.1326500430657208 2731    none
# Name: Class, dtype: object
# Tonight's #MKR confirms the casting people trawl the dark depths of the seriously delusional, the supremely misguided &amp; plain rotten cooks. 0.13364636592679777 1116    hate
# Name: Class, dtype: object
# Tonight's #MKR confirms the casting people trawl the dark depths of the seriously delusional, the supremely misguided &amp; plain rotten cooks. 0.13364636592679777 1116    none
# Name: Class, dtype: object
# #MKR  Lost the plot - where's the big Texan with the elephant sized steaks that they all have for brekkie ? 0.1364994727662335 636     hate
# 2358    hate
# 4014    none
# Name: Class, dtype: object
# #MKR  Lost the plot - where's the big Texan with the elephant sized steaks that they all have for brekkie ? 0.1364994727662335 636     none
# 2358    none
# 4014    none
# Name: Class, dtype: object
# #MKR  Lost the plot - where's the big Texan with the elephant sized steaks that they all have for brekkie ? 0.1364994727662335 636     none
# 2358    none
# 4014    none
# Name: Class, dtype: object
# #MKR  Lost the plot - where's the big Texan with the elephant sized steaks that they all have for brekkie ? 0.1364994727662335 636     none
# 2358    none
# 4014    none
# Name: Class, dtype: object
# #MKR  Lost the plot - where's the big Texan with the elephant sized steaks that they all have for brekkie ? 0.1364994727662335 636     none
# 2358    none
# 4014    none
# Name: Class, dtype: object
# #MKR  Lost the plot - where's the big Texan with the elephant sized steaks that they all have for brekkie ? 0.1364994727662335 636     hate
# 2358    hate
# 4014    hate
# Name: Class, dtype: object
# omg, you guys. they are misusing the word gaslighting repeatedly. must not have gotten to that on their SJW word of the day calendar yet. 0.13776314269895773 5624    none
# Name: Class, dtype: object
# omg, you guys. they are misusing the word gaslighting repeatedly. must not have gotten to that on their SJW word of the day calendar yet. 0.13776314269895773 5624    hate
# Name: Class, dtype: object
# Fuck you, fuck you very very mu~ch, Lily Allen. Your latest video is racist and awful and does nothing to promote "feminism." Christ. 0.13913508818448034 4041    none
# Name: Class, dtype: object
# Fuck you, fuck you very very mu~ch, Lily Allen. Your latest video is racist and awful and does nothing to promote "feminism." Christ. 0.13913508818448034 4041    hate
# Name: Class, dtype: object
# Every day I'm reminded that the most dangerous men are not the "lol women can't drive" crew, but the "I'm not sexist, but" DERAILMENT crowd. 0.14404186896538906 4590    none
# Name: Class, dtype: object
# Every day I'm reminded that the most dangerous men are not the "lol women can't drive" crew, but the "I'm not sexist, but" DERAILMENT crowd. 0.14404186896538906 4590    hate
# Name: Class, dtype: object
# Kat is going to be so smug she's going to be declared the particularly smug mayor of smugtown on the isle of smuggy #MKR 0.15466280368482047 1863    hate
# Name: Class, dtype: object
# Kat is going to be so smug she's going to be declared the particularly smug mayor of smugtown on the isle of smuggy #MKR 0.15466280368482047 1863    none
# Name: Class, dtype: object
# @Venomous9 my views are largely tempered by my former tax bracket. and although i like the idea of flat tax, doesn't work well at pov lvl. 0.1637000288215154 5756    none
# Name: Class, dtype: object
# @Venomous9 my views are largely tempered by my former tax bracket. and although i like the idea of flat tax, doesn't work well at pov lvl. 0.1637000288215154 5756    hate
# Name: Class, dtype: object
# RT @MikeFields__: To be honest I like the idea of the wife cooking and cleaning and the guy earning all the money to support their family, … 0.19888615449654665 2623    hate
# Name: Class, dtype: object
# RT @MikeFields__: To be honest I like the idea of the wife cooking and cleaning and the guy earning all the money to support their family, … 0.19888615449654665 2623    none
# Name: Class, dtype: object
#
# Total Amount of Re-annotations: 544

# %%
data_stat(idf)

# Data Split
i_X_train, i_X_test, i_Y_train, i_Y_test = train_test_split(idf.Tweets, idf.Class, test_size=0.2)

i_vectorizer = CountVectorizer(analyzer = "word",tokenizer = None,preprocessor = None,stop_words = None,max_features = 5000)

i_train_data_features = i_vectorizer.fit_transform(i_X_train)
i_train_data_features = i_train_data_features.toarray()

i_test_data_features = i_vectorizer.transform(i_X_test)
i_test_data_features = i_test_data_features.toarray()

# Classifier
i_clf = svm.SVC(kernel='linear', C=1.0)

print("\nTraining Intelligent Sampling SVM")
i_clf.fit(i_train_data_features,i_Y_train)

print("\nTesting Intelligent Sampling SVM")
i_predicted = i_clf.predict(i_test_data_features)

i_accuracy = np.mean(i_predicted==i_Y_test)
# TO-DO: Format Accuracy Str
print ("\nIntelligent Accuracy: ",i_accuracy)
# Out:
# Number of samples: 6000
# Number of Hate Samples: 2959
# Number of non-Hate Samples: 3041
#
# Training Intelligent Sampling SVM
#
# Testing Intelligent Sampling SVM
#
# Intelligent Accuracy:  0.8841666666666667
